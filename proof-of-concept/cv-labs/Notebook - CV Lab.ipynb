# %%
import os
from google.colab import drive
contentPath = "/content/"
if not os.path.exists(contentPath + 'drive'):
  drive.mount( contentPath + 'drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
lab_dir = '/content/drive/MyDrive/23-24_CE901-SL_CE902-SU_ogbuitepu_patrick_o/proof-of-concept/cv-labs'

# %%
os.chdir(lab_dir)

# %%
# !cd $lab_dir
# !ls
# Out:
#  2006-10-23-001.jpg   display.py  'Notebook - CV Lab.ipynb'   sxcv.py
#  2006-10-23-002.jpg   fruit.png    __pycache__		      sxcv.py~
#  2006-10-23-003.jpg   m51.png	   review.py		      sx.jpg

# %%
# !python review.py sx.jpg
# Out:
# sx.jpg has 3 channels of size 512 rows x 512 columns with uint8 pixels.

# %% [markdown]
# ## Testing Functions

# %%
# !python -m doctest sxcv.py
